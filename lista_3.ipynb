# %%
# !pip install -U -q PyDrive

import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns


import numpy as np

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import drive
from oauth2client.client import GoogleCredentials
from os.path import exists as file_exists


# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
googleDrive = GoogleDrive(gauth)


drive.mount('/content/gdrive')

#leitura do arquivo
# !ls "/content/gdrive/MyDrive/Colab Notebooks/"
file = '/content/gdrive/MyDrive/Colab Notebooks/files/1.csv'

file2 = '/content/gdrive/MyDrive/Colab Notebooks/files/accelerometer-1591009614.csv'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#  CdiasExercicio2.ipynb	   ImagemCloud.ipynb   medidas_estatisticas.ipynb
#  estatistica		   Lista1-IA.ipynb     palavras.txt
#  Exercicio2-parte2.ipynb   lista1.ipynb        parrot.ipynb
#  Exercicios-2.ipynb	   lista2.ipynb       'Política e COVID.ipynb'
#  files			   Lista3-2.ipynb
#  IA-LAB1		   lista3.ipynb

# %%
#Abre o arquivo
def ler_arquivo_csv(arquivo = '', delimter = ','):
    content = '';
    try:
      with csv.reader(arquivo, 'r') as file:
        content = file.read()
        content.encode('UTF-8')
        print(content)
        file.close
    except FileNotFoundError:
        print("Arquivo não existe")
    except e:
        print(e.errno)
    return content

# %%
working_at_computer = []
standing_up = []
standing = []
walking = []
going_updown_stairs = []
walking_and_talking = []
talking_while_standing = []

idxes = []

with open(file, newline='') as csvfile:
     spamreader = csv.reader(csvfile, delimiter=',')
     for row in spamreader:
       idxes.append(int(float(row[0])) +1 )
       if (row[4] == '1'):
         working_at_computer.append(row)
       elif (row[4] == '2'):
         standing_up.append(row)
       elif (row[4]=='3'):
         standing.append(row)
       elif (row[4]=='4'):
         walking.append(row)
       elif (row[4]=='5'):
         going_updown_stairs.append(row)
       elif (row[4]=='6'):
         walking_and_talking.append(row)
       elif (row[4]=='7'):
         talking_while_standing.append(row)

# %%
w0, w1, w2, w3 = [],[],[],[]
for vetor1 in working_at_computer:
  w0.append(int(vetor1[0]))
  w1.append(int(vetor1[1]))
  w2.append(int(vetor1[2]))
  w3.append(int(vetor1[3]))

list_of_tuples = list(zip(w0, w1, w2, w3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("working_at_computer")
plt.show()

w_xmedia = []
w_xmedia.append(w1)
w_xmedia.append(w2)
w_xmedia.append(w3)

#media_w = np.median(w_xmedia)



#loan_amount = cur.fetchall()
#loan_amount = np.array(w1,dtype='int') #setting up the array in numpy
x ,y  = np.unique(w1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(w2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(w3,return_counts=True)
plt.scatter(x,y)
plt.title("working_at_computer")
plt.show()



su0,su1, su2, su3 = [],[],[],[]
for vetor1 in standing_up:
  su0.append(int(vetor1[0]))
  su1.append(int(vetor1[1]))
  su2.append(int(vetor1[2]))
  su3.append(int(vetor1[3]))


list_of_tuples = list(zip(su0, su1, su2, su3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("standing_up")
plt.show()

su_media = []
su_media.append(su1)
su_media.append(su2)
su_media.append(su3)


x ,y  = np.unique(su1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(su2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(su3,return_counts=True)
plt.scatter(x,y)
plt.title("standing_up")
plt.show()

s0,s1, s2, s3 = [],[],[],[]
for vetor1 in standing:
  s0.append(int(vetor1[0]))
  s1.append(int(vetor1[1]))
  s2.append(int(vetor1[2]))
  s3.append(int(vetor1[3]))

list_of_tuples = list(zip(s0, s1, s2, s3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("standing")
plt.show()

s_media = []
s_media.append(s1)
s_media.append(s2)
s_media.append(s3)


x ,y  = np.unique(s1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(s2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(s3,return_counts=True)
plt.scatter(x,y)
plt.title("standing")
plt.show()


#####

wa0, wa1, wa2, wa3 = [],[],[],[]
for vetor1 in walking:
  wa0.append(int(vetor1[0]))
  wa1.append(int(vetor1[1]))
  wa2.append(int(vetor1[2]))
  wa3.append(int(vetor1[3]))

list_of_tuples = list(zip(wa0, wa1, wa2, wa3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("walking")
plt.show()

w_media = []
w_media.append(s1)
w_media.append(s2)
w_media.append(s3)

x ,y  = np.unique(wa1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(wa2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(wa3,return_counts=True)
plt.scatter(x,y)
plt.title("walking")
plt.show()

#####

gus0,gus1, gus2, gus3 = [],[],[],[]
for vetor1 in going_updown_stairs:
  gus0.append(int(vetor1[0])) 
  gus1.append(int(vetor1[1]))
  gus2.append(int(vetor1[2]))
  gus3.append(int(vetor1[3]))

list_of_tuples = list(zip(gus0, gus1, gus2, gus3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("going_updown_stairs")
plt.show()

gus_media = []
gus_media.append(gus1)
gus_media.append(gus2)
gus_media.append(gus3)



x ,y  = np.unique(gus1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(gus2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(gus3,return_counts=True)
plt.scatter(x,y)
plt.title("going_updown_stairs")
plt.show()

#####

wat0, wat1, wat2, wat3 = [],[],[],[]
for vetor1 in walking_and_talking:
  wat0.append(int(vetor1[0]))  
  wat1.append(int(vetor1[1]))
  wat2.append(int(vetor1[2]))
  wat3.append(int(vetor1[3]))

list_of_tuples = list(zip(wat0, wat1, wat2, wat3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("walking_and_talking")
plt.show()

wat_media = []
wat_media.append(wat1)
wat_media.append(wat2)
wat_media.append(wat3)

x ,y  = np.unique(wat1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(wat2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(wat3,return_counts=True)
plt.scatter(x,y)
plt.title("walking_and_talking")
plt.show()


#####

tws0, tws1, tws2, tws3 = [],[],[],[]
for vetor1 in talking_while_standing:
  tws0.append(int(float(vetor1[0])))
  tws1.append(int(vetor1[1]))
  tws2.append(int(vetor1[2]))
  tws3.append(int(vetor1[3]))

list_of_tuples = list(zip(tws0, tws1, tws2, tws3))   
# Assign data to tuples.
list_of_tuples 
# Converting lists of tuples into
# pandas Dataframe.
df2s = pd.DataFrame(list_of_tuples, columns = ['timestamp', 'x', 'y', 'z'])
plt.plot(df2s['timestamp'], df2s['x'], label='amostra de x')
plt.plot(df2s['timestamp'], df2s['y'], label='amostra de y')
plt.plot(df2s['timestamp'], df2s['z'], label='amostra de z')
plt.legend()
plt.title("talking_while_standing")
plt.show()

tws_media = []
tws_media.append(wat1)
tws_media.append(wat2)
tws_media.append(wat3)

x ,y  = np.unique(tws1, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

x ,y = np.unique(tws2,return_counts=True)
plt.scatter(x,y)

x ,y = np.unique(tws3,return_counts=True)
plt.scatter(x,y)
plt.title("talking_while_standing")
plt.show()

# %% [markdown]
# Valores máximos de X,Y,Z
#
# working_at_computer
# standing_up
# standing
# walking
# going_updown_stairs
# walking_and_talking
# talking_while_standing

# %%
dicionario = {}

pandas_table = pd.DataFrame({ 'working_at_computer_x_max': [np.max(w1)], 'working_at_computer_y_max': [np.max(w2)] , 'working_at_computer_z_max': [np.max(w3)], 
                            'working_at_computer_x_min': [np.min(w1)], 'working_at_computer_y_min': [np.min(w2)] , 'working_at_computer_z_min': [np.min(w3)],
                            'standing_up_x_max': [np.max(su1)], 'standing_up_y_max': [np.max(su2)], 'standing_up_z_max': [np.max(su3)],
                            'standing_up_x_min': [np.min(su1)], 'standing_up_y_min': [np.min(su2)], 'standing_up_z_min': [np.min(su3)],
                            'standing_x_max': [np.max(s1)], 'standing_y_max': [np.max(s2)], 'standing_z_max': [np.max(s3)],
                            'standing_x_min': [np.min(s1)], 'standing_x_min': [np.min(s2)], 'standing_x_min': [np.min(s3)],
                            'walking_x_max': [np.max(wa1)], 'walking_y_max': [np.max(wa2)], 'walking_z_max': [np.max(wa3)],
                            'walking_x_min': [np.min(wa1)], 'walking_x_min': [np.min(wa2)], 'walking_z_min': [np.min(wa3)],
                            'going_updown_stairs_x_max': [np.max(gus1)], 'going_updown_stairs_y_max': [np.max(gus2)], 'going_updown_stairs_z_max': [np.max(gus3)],
                            'going_updown_stairs_x_min': [np.min(gus1)], 'going_updown_stairs_x_min': [np.min(gus2)], 'going_updown_stairs_z_min': [np.min(gus3)],
                            'walking_and_talking_x_max': [np.max(wat1)], 'walking_and_talking_y_max': [np.max(wat2)], 'walking_and_talking_z_max': [np.max(wat3)],
                            'walking_and_talking_x_min': [np.min(wat1)], 'walking_and_talking_x_min': [np.min(wat2)], 'walking_and_talking_z_min': [np.min(wat3)],
                            'talking_while_standing_x_max': [np.max(tws1)], 'talking_while_standing_y_max': [np.max(tws2)], 'talking_while_standing_z_max': [np.max(tws3)],
                            'talking_while_standing_x_min': [np.min(tws1)], 'talking_while_standing_x_min': [np.min(tws2)], 'talking_while_standing_z_min': [np.min(tws3)]})



display(pandas_table)
# Out:
#    working_at_computer_x_max  ...  talking_while_standing_z_min
# 0                       2356  ...                           994
#
# [1 rows x 36 columns]

# %% [markdown]
# Média,
# Mediana,
# Variância Amostral,
# Desvio Padrão

# %% [markdown]
# Interquartile Range(IQR)
#
# A medida de variabilidade IQR, com base na divisão de um conjunto de dados em quartis chamados de primeiro, segundo e terceiro quartis; e eles são denotados por Q1, Q2 e Q3, respectivamente.
#
#     Q1 é o valor médio na primeira metade.
#     Q2 é o valor médio do conjunto.
#     Q3 é o valor médio na segunda metade.

# %%
print('Mediana (working_at_computer): ', np.median(w_xmedia, keepdims = False))
print('Média (working_at_computer): ', np.mean(w_xmedia))
#print('Média (working_at_computer): ', np.mean(w_xmedia, axis=0, keepdims = True))
#print('Média (working_at_computer): ', np.mean(w_xmedia, axis=1, keepdims = True))

print('Variância amostral (working_at_computer): ', np.var(w_xmedia))
print('Desvio Padrão (working_at_computer): ', np.std(w_xmedia))
#print('Variância populacional (working_at_computer): ', np.var(w_xmedia, ddof = 0))

#dicionario.update({'media working_at_computer': np.mean(w_xmedia)})

print("Q2 quantile de working_at_computer : ", np.quantile(w_xmedia, .50))
print("Q1 quantile de working_at_computer : ", np.quantile(w_xmedia, .25))
print("Q3 quantile de working_at_computer : ", np.quantile(w_xmedia, .75))
    


##########################################################################################

print('Mediana (standing_up): ', np.median(su_media, keepdims = False))
print('Média (standing_up): ', np.mean(su_media))

print('Variância amostral (standing_up): ', np.var(su_media))
print('Desvio Padrão (standing_up): ', np.std(su_media))
#print('Variância populacional (standing_up): ', np.var(su_media, ddof = 0))

print("Q2 quantile de standing_up : ", np.quantile(su_media, .50))
print("Q1 quantile de standing_up : ", np.quantile(su_media, .25))
print("Q3 quantile de standing_up : ", np.quantile(su_media, .75))


##########################################################################################

print('Mediana (standing): ', np.median(s_media, keepdims = False))
print('Média (standing): ', np.mean(s_media))

print('Variância amostral (standing): ', np.var(s_media))
print('Desvio Padrão (standing): ', np.std(s_media))
#print('Variância populacional (standing): ', np.var(s_media, ddof = 0))

print("Q2 quantile de standing : ", np.quantile(s_media, .50))
print("Q1 quantile de standing : ", np.quantile(s_media, .25))
print("Q3 quantile de standing : ", np.quantile(s_media, .75))

##########################################################################################

print('Mediana (walking_and_talking): ', np.median(wat_media, keepdims = False))
print('Média (walking_and_talking): ', np.mean(wat_media))

print('Variância amostral (walking_and_talking): ', np.var(wat_media,))
print('Desvio Padrão (walking_and_talking): ', np.std(wat_media))
#print('Variância populacional (walking_and_talking): ', np.var(wat_media, ddof = 0))

print("Q2 quantile de walking_and_talking : ", np.quantile(wat_media, .50))
print("Q1 quantile de walking_and_talking : ", np.quantile(wat_media, .25))
print("Q3 quantile de walking_and_talking : ", np.quantile(wat_media, .75))

##########################################################################################

print('Mediana (talking_while_standing): ', np.median(tws_media, keepdims = False))
print('Média (talking_while_standing): ', np.mean(tws_media))

print('Variância amostral (talking_while_standing): ', np.var(tws_media))
print('Variância amostral (talking_while_standing): ', np.var(tws_media))
#print('Variância populacional (talking_while_standing): ', np.var(wat_media, ddof = 0))

print("Q2 quantile de talking_while_standing : ", np.quantile(tws_media, .50))
print("Q1 quantile de talking_while_standing : ", np.quantile(tws_media, .25))
print("Q3 quantile de talking_while_standing : ", np.quantile(tws_media, .75))

##########################################################################################

print('Mediana (going_updown_stairs): ', np.median(gus_media, keepdims = False))
print('Média (going_updown_stairs): ', np.mean(gus_media))

print('Variância amostral (going_updown_stairs): ', np.var(gus_media))
print('Variância amostral (going_updown_stairs): ', np.var(gus_media))
#print('Variância populacional (talking_while_standing): ', np.var(wat_media, ddof = 0))

print("Q2 quantile de going_updown_stairs : ", np.quantile(gus_media, .50))
print("Q1 quantile de going_updown_stairs : ", np.quantile(gus_media, .25))
print("Q3 quantile de going_updown_stairs : ", np.quantile(gus_media, .75))

##########################################################################################

print('Mediana (walking): ', np.median(w_media, keepdims = False))
print('Média (walking): ', np.mean(w_media))

print('Variância amostral (walking): ', np.var(w_media, ddof = 1))
print('Variância amostral (walking): ', np.var(w_media))
#print('Variância populacional (talking_while_standing): ', np.var(wat_media, ddof = 0))


print("Q2 quantile de walking : ", np.quantile(w_media, .50))
print("Q1 quantile de walking : ", np.quantile(w_media, .25))
print("Q3 quantile de walking : ", np.quantile(w_media, .75))
# Out:
# Mediana (working_at_computer):  2120.0
# Média (working_at_computer):  2152.3515455652228
# Variância amostral (working_at_computer):  28916.02214326454
# Desvio Padrão (working_at_computer):  170.04711742121518
# Q2 quantile de working_at_computer :  2120.0
# Q1 quantile de working_at_computer :  1973.0
# Q3 quantile de working_at_computer :  2371.0
# Mediana (standing_up):  2054.0
# Média (standing_up):  2112.0398706896553
# Variância amostral (standing_up):  42217.25810860397
# Desvio Padrão (standing_up):  205.46838712708086
# Q2 quantile de standing_up :  2054.0
# Q1 quantile de standing_up :  1909.0
# Q3 quantile de standing_up :  2353.0
# Mediana (standing):  2023.0
# Média (standing):  2098.6186136775937
# Variância amostral (standing):  43761.11767572229
# Desvio Padrão (standing):  209.1915812735357
# Q2 quantile de standing :  2023.0
# Q1 quantile de standing :  1904.0
# Q3 quantile de standing :  2380.0
# Mediana (walking_and_talking):  2025.0
# ...

# %%
print('Total de amostras working_at_computer = ', len(working_at_computer))
print('Total de amostras standing_up = ', len(standing_up))
print('Total de amostras standing = ', len(standing))
print('Total de amostras walking = ', len(walking))
print('Total de amostras going_updown_stairs = ', len(going_updown_stairs))
print('Total de amostras walking_and_talking = ', len(walking_and_talking))
print('Total de amostras talking_while_standing = ', len(talking_while_standing))

print('\nExiste uma correlação entre os sinais ambos aumentam e diminuem com a intensidade do esforço,\napresentam o formato de uma distribuição normal.')
print('Taxa de Amostragem 52 Hz')
# Out:
# Total de amostras working_at_computer =  33677
# Total de amostras standing_up =  928
# Total de amostras standing =  7901
# Total de amostras walking =  12649
# Total de amostras going_updown_stairs =  3191
# Total de amostras walking_and_talking =  2917
# Total de amostras talking_while_standing =  50487
#
# Existe uma correlação entre os sinais ambos aumentam e diminuem com a intensidade do esforço,
# apresentam o formato de uma distribuição normal.
# Taxa de Amostragem 52 Hz
